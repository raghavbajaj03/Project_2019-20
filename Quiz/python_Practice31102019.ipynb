# %%
import PySimpleGUI as sg
import pandas as pd
import numpy as np
import wikipedia
import pyttsx3
import numpy as np
import matplotlib.pyplot as plt
import sqlite3
import time
import pygame
from reportlab.pdfgen import canvas
from reportlab.lib import pdfencrypt
import threading
import datetime

# %matplotlib inline


df=pd.read_excel("Quiz_Qestion.xlsx")
#print(df)
##############################CONNECTION WITH SQL DATABASE AND CREATEION DATABASES#####################################
conn = sqlite3.connect('Users.db')
c = conn.cursor()

c.execute("""CREATE TABLE IF NOT EXISTS user (
            Username VARCHAR(20) NOT NULL,
            First_Name VARCHAR(20) NOT NULL,
            Last_Name VARCHAR(20) NOT NULL,
            Email VARCHAR(20) NOT NULL,
            Password VARCHAR(20) NOT NULL
            )""")
conn.commit()
"""
########################################CODE FOR SPEAK RESULTS#########################################################  
engine=pyttsx3.init("sapi5")
voices=engine.getProperty("voices")
#print(voices[1].id)
engine.setProperty("voice",voices[0].id)



def speak(audio):
    engine.say(audio)
    engine.runAndWait() 

#####################################FUNCTION FOR WISH THE USER########################################################
def wishMe():
    hour=int(datetime.datetime.now().hour)
    if hour>=0 and hour<12:
        speak("good morning")
    elif hour>=12 and hour<16:
        speak("good afternoon")
    elif hour>=16 and hour<18:
        speak("good evening")
    else:
        speak("good night")
    #speak("This is quiz generator,Let start the Quizz ")
wishMe()
#####################################FUNCTION FOR ADDIND NEW USER######################################################
def new_user():
    with conn:
        insert=('INSERT INTO user VALUES (?,?,?,?,?)')
        c.execute(insert,[values["name"],values["first_name"],values["last_name"],values["email"],values["password"]])
        conn.commit()
        r=c.fetchall()
        if r:
            for i in r:
                print("Welcome"+i[1]+"you have registered")
                window1.Close()
                break
####################################FUNCTION FOR LOGIN USER############################################################
def login():
    with conn:
        find_user=("SELECT * FROM User WHERE Username=? AND Email=? AND Password=?")
        c.execute(find_user,([(name),(email),(password)]))
        results=c.fetchall()
                
        if results:
            for i in results:
                print("Welcome"+i[1])
                break
        else:
            print("Username and password not recognised")
            again=input("Do you want to try again?y/n ")
            if again.lower()=="n":
                print("Goodbye")
                #speak("Goodbye")
                time.sleep(.1)
            elif again.lower()=="y":
                print("Please enter username and password ")
                time.sleep(.1)
            window2.Close()
            
##############################CODE FOR START QUIZ#####################################################################                
layout=[ [sg.ReadFormButton(' ', button_color=sg.TRANSPARENT_BUTTON,
                                image_filename="adobe-spark-post.png", image_size=(600, 600), image_subsample=2, 
                                border_width=0)],
         [sg.Text('Click image to start Quiz')]]
Start_window= sg.Window('Start_Quiz_Application').Layout(layout)
while True:
    event,values=Start_window.Read()
    print("event= ", event,"values=",values)
####################CODE FOR SELECTING REGISTRATION WINDOW OR LOGIN WINDOW#############################################
    #Start_window.Hide()
#if(event==" "):
layout=[
        [sg.Text("Please Select Appropriate Option For Start Quiz",size=(30,7),font="Helvetica 15")],
        [sg.Button("Register_for_Quiz"), sg.Button("Login_in_Quiz")]
]
window= sg.Window('SELECTING_REGISTRATION_WINDOW_OR_LOGIN_WINDOW').Layout(layout)
#speak("Click on Register_for_Quiz Button to Register your self for quiz or Click on Login_in_Quiz to Login to Quiz")
while True:
    event,values=window.Read()
    print("event= ", event,"values=",values)
###########################################CODE FOR REGISTRATION WINDOW################################################
    if(event=="Register_for_Quiz"):
        window.Close()
        layout1=[
                [sg.Text("User Registration",size=(20,3),font="Courier 15")],
                [sg.Text('User Name', size=(15, 1)), sg.InputText('',key="name")],
                [sg.Text('First_Name', size=(15, 1)), sg.InputText('',key="first_name")],
                [sg.Text('Last_Name', size=(15, 1)), sg.InputText('',key="last_name")],
                [sg.Text('Email', size=(15, 1)), sg.InputText('',key="email")],
                [sg.Text('Password', size=(15, 1)), sg.InputText('',key="password")],
                [sg.Button("Submit"), sg.Button("Exit")]
        ]
        
        window1= sg.Window('Registration_For_Quiz_Application').Layout(layout1)
        #speak("You had click on Register_for_Quiz Button to Register, Now enter User Name,First_Name,Last_Name,Email,Password")
        
        while True:
            event,values=window1.Read()
            print("event= ", event,"values=",values)
            if(event=="Submit"):
                new_user()        
            elif(event is None or event=="Exit"):
                window1.Close()
                break 
            break    
####################################CODE FOR LOGIN WINDOW##############################################################
    elif(event=="Login_in_Quiz"):
        window.Close()
        layout2=[
                [sg.Text("User Login",size=(15,3),font="Courier 15")],
                [sg.Text('User Name', size=(15, 1)), sg.InputText('',key="name1")],
                [sg.Text('Email', size=(15, 1)), sg.InputText('',key="email1")],
                [sg.Text('Password', size=(15, 1)), sg.InputText('',key="password1")],
                [sg.Button("Login"), sg.Button("Exit")]
        ]
    
        window2= sg.Window('Login_For_Quiz_Application').Layout(layout2)
        #speak("You had click on Login_in_Quiz Button to Login, Now enter User Name,Email,Password")
        while True:
            event2,values2=window2.Read()
            print("event= ", event2,"values=",values2)
            #Start_window.Close()
            name=values2["name1"]
            email=values2["email1"]
            password=values2["password1"]
            if(event2=="Login"):
                login()                
            elif(event is None or event=="Exit"):
                window2.Close()
                break
            break
        break  
########################################CODE FOR TIMER SOUND###########################################################    
def Sound():
    pygame.mixer.init()
    pygame.mixer.music.load("tictiksound.mp3")
    pygame.mixer.music.play()
########################################CODE FOR TIMER SOUND###########################################################
def Alarm():
    pygame.mixer.init()
    pygame.mixer.music.load("LoudAlarm.mp3")
    pygame.mixer.music.play()"""
#########################################CODE FOR TIMER################################################################    
def time_as_int():
    return int(round(time.time() * 100))
########################################CODE FOR GENERATION OF QUIZ####################################################       
   
list=[]
l1=[]    
list_Y=[]    
Score=0
layout4=[
        [sg.Text("",key="Question")],
        [sg.Radio("","Radio",key="Radio1")],
        [sg.Radio("","Radio",key="Radio2")],
        [sg.Radio("","Radio",key="Radio3")],
        [sg.Radio("","Radio",key="Radio4")],
        #commented this to run my code: Total lines=
        [sg.Text("", size=(15, 2),font=('Helvetica', 20), justification='center', key="_timer")],
        [sg.Button("Next"),sg.Button("Lock_Answer"),sg.Button("Quit")]]
window4= sg.Window('Quiz_Application').Layout(layout4)
#current_time, paused_time, paused = 0, 0, False
#start_time = time_as_int()
for i in range(10):
    r=np.random.randint(0,30)
    print(r)
a=str(df.iloc[r,1])
a=33.4    
while True:
    
    window4.Element('Question').Update(f '.{a}.')
    #window4.Element('Radio1').Update(str(df.iloc[r,2]))
    #window4.Element('Radio2').Update(str(df.iloc[r,3]))
    #window4.Element('Radio3').Update(str(df.iloc[r,4]))
    #window4.Element('Radio4').Update(str(df.iloc[r,5]))
    event,values=window4.Read()
    l=values
    print("event= ", event,"values=",values)
    #break
    if(event=="Lock_Answer"):
        if(l["Radio1"]==True):
            l1.append([df.iloc[r,1],df.iloc[r,2],df.iloc[r,6]])
            list.append(l1)
            l1=[]
            if(df.iloc[r,2]==df.iloc[r,6]):
                print("Your Answer is correct")
                Score+=10
                list_Y.append(Score)
                window4.Close()
            else:
                print("Your Answer is Wrong")
                list_Y.append(0)
                window4.Close()

        elif(l["Radio2"]==True):
            l1.append([df.iloc[r,1],df.iloc[r,3],df.iloc[r,6]])
            list.append(l1)
            l1=[]
            if(df.iloc[r,3]==df.iloc[r,6]):
                print("Your Answer is correct")
                Score+=10
                list_Y.append(Score)
                window4.Close()
            else:
                print("Your Answer is Wrong")
                list_Y.append(0)
                window4.Close()

        elif(l["Radio3"]==True):
            l1.append([df.iloc[r,1],df.iloc[r,4],df.iloc[r,6]])
            list.append(l1)
            l1=[]
            if(df.iloc[r,4]==df.iloc[r,6]):
                print("Your Answer is correct")
                Score+=10
                list_Y.append(Score)
                window4.Close()
            else:
                print("Your Answer is Wrong")
                list_Y.append(0)
                window4.Close()

        elif(l["Radio4"]==True):
            l1.append([df.iloc[r,1],df.iloc[r,4],df.iloc[r,6]])
            list.append(l1)
            l1=[]
            if(df.iloc[r,5]==df.iloc[r,6]):
                print("Your Answer is correct")
                Score+=10
                list_Y.append(Score)
                window4.Close()
            else:
                print("Your Answer is Wrong")
                list_Y.append(0)
                window4.Close()
        else:
            #print("Your Answer is Wrong")
            l1.append([df.iloc[r,1],"No Answer Entered",df.iloc[r,6]])
            print("Correct Answer")
            print(str(df.iloc[r,6]))
        try:
            print("Correct Answer")
            print(str(df.iloc[r,6]))
            summary2=wikipedia.summary(str(df.iloc[r,6]),sentences=5)
            print(summary2)
            #speak(summary2)
        except:
            print("No Page Found on WIKIPEDIA")
            #speak("No Page Found on WIKIPEDIA")
            #summary=wikipedia.summary(str(df.iloc[r,1]),sentences=5)
            #print(str(df.iloc[r,1]))
            #print(summary)
            #speak(summary)

    elif(event is None or event=="Quit"):
        len=len(list_Y)
        if(len<10):
            re=10-len
            for i in range(re):
                list_Y.append(0)
                print(list_Y)
        window4.Close()        
        break
    elif(event=="Next"):
        #my code line 9
        #timer_running = not timer_running
        continue


#########################################CODE FOR SUBMIT WINDOW########################################################
layout5=[
[sg.Button("Submit")]
]
window5 = sg.Window('Quiz_Application_Submit').Layout(layout5)
while True:
    event,values=window5.Read()
    print("event= ", event,"values=",values)
    if(event=="Submit"):
        print("Score=",Score)
        x=np.arange(1,11,1)
        y=list_Y
        print(y)
        plt.plot(x,y)
        plt.title("Performance Chart")
        plt.xlabel("Question No.")
        plt.ylabel("Score")
        plt.savefig("Figure.png")
        window5.Close()
    plt.show()

#####################################CODE FOR GENERATING REPORT CARD IN PDF FORM#######################################
# Out:
# 7
# 2
# 29
# 13
# 18
# 4
# 25
# 20
# 9
# 25
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-11-5b731a8f40ac> in <module>
#     203 while True:
#     204
# --> 205     window4.Element('Question').Update(f".{a}.")
#     206     #window4.Element('Radio1').Update(str(df.iloc[r,2]))
#     207     #window4.Element('Radio2').Update(str(df.iloc[r,3]))
#
# ~\Anaconda3\lib\site-packages\PySimpleGUI\PySimpleGUI.py in Update(self, value, background_color, text_color, font, visible)
#    1203             self.DisplayText = value
#    1204             stringvar = self.TKStringVar
# -> 1205             stringvar.set(value)
#    1206         if background_color is not None:
#    1207             self.TKText.configure(background=background_color)
#
# AttributeError: 'NoneType' object has no attribute 'set'

# %%
        """current_time = time_as_int() - start_time
        window4.FindElement('_timer').Update('{:02d}'.format((30-((current_time // 100) % 60))%31))
        if ((((current_time // 100) % 60)%31)==30):
            #window4.Close()
            break"""

# %%
window4.Element('Question').Update(str(df.iloc[r,1]))
    window4.Element('Radio1').Update(str(df.iloc[r,2]))
    window4.Element('Radio2').Update(str(df.iloc[r,3]))
    window4.Element('Radio3').Update(str(df.iloc[r,4]))
    window4.Element('Radio4').Update(str(df.iloc[r,5]))

# %%
import time
time=time.time()
print(time)
days=time//(24*3600)
time=time%(24*3600)
hour=int(time//3600)
time=time%3600
minutes=int(time//60)
time=time//60
seconds=int(time)
current_time=str(hour)+":"+str(minutes)+":"+str(seconds)
print(current_time)
# Out:
# 1577605422.4306412
# 7:43:43

# %%
from reportlab.pdfgen import canvas
from reportlab.lib import pdfencrypt
from reportlab.lib.units import inch
from reportlab.platypus.tables import Table, TableStyle 
from reportlab.lib import colors 
from reportlab.lib.enums import TA_LEFT, TA_CENTER, TA_RIGH
import datetime
enc=pdfencrypt.StandardEncryption("1234",canPrint=1)
pdf=canvas.Canvas("Project_demo.pdf",bottomup=0,encrypt=enc)
pdf.translate(inch,inch)
fonts=pdf.getAvailableFonts()
print(fonts)
################## Heading #############################################################################################
pdf.setFont("Courier-BoldOblique",40)
pdf.setFillColor("orange")
pdf.drawCentredString(250,50,"Report For Quiz")
################# Username,EmailId,Date,Time ###########################################################################
pdf.setFont("Courier-Bold",20)
pdf.setFillColor("cyan")
pdf.drawString(0,100,"Username:"+values2["name1"])
pdf.setFillColor("cornflower")
pdf.drawString(0,130,"Email_ID:"+values2["email1"])
pdf.setFillColor("thistle")
pdf.drawString(330,100,"Date:"+str(datetime.date.today()))
pdf.setFillColor("cadetblue")
pdf.drawString(330,130,"Time:"+str(current_time))
table=Table(list)
pdf.build(table)
pdf.save()

# %%
import PySimpleGUI as sg
import datetime
import random

# Displaying information using PySimpleGUI

# 1 - Debug output by calling Print
for x in range(20):
    sg.Print(x, datetime.datetime.now())
# 2 - A custom window with Output Element

# STEP 1 define the layout
layout = [  [sg.Text('This is your custom window... print output is below')],
            [sg.Output(size=(40,6))],
            [sg.Text(size=(40,1), key='-LINE-OUTPUT-')],
            [sg.Button('Print Something'), sg.Button('Popup'), sg.Button('Exit')]  ]
           
# STEP 2 - create the window
window = sg.Window('My new window', layout)

# STEP3 - the event loop
while True:
    random_number = random.randint(0,10)

    event, values = window.read()   # Read the event that happened and the values dictionary
    
    if event in (None, 'Exit'):     # If user closed window with X or if user clicked "Exit" button then exit
        break
    elif event == 'Popup':    # 3 - Display using a popup window
        sg.popup(f'{random_number}   {datetime.datetime.now()}')
    else:
        print(f'{random_number}   {datetime.datetime.now()}')
        window['-LINE-OUTPUT-'].update(f'{random_number}   {datetime.datetime.now()}') # 4 - Update a Text element
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-12-17fecddfc655> in <module>
#      13 layout = [  [sg.Text('This is your custom window... print output is below')],
#      14             [sg.Output(size=(40,6))],
# ---> 15             [sg.Text(size=(40,1), key='-LINE-OUTPUT-')],
#      16             [sg.Button('Print Something'), sg.Button('Popup'), sg.Button('Exit')]  ]
#      17
#
# TypeError: __init__() missing 1 required positional argument: 'text'

# %%
"""def new_user():
                    with conn:
                        insert=('INSERT INTO user VALUES (?,?,?,?,?)')
                        c.execute(insert,in_value)
                        conn.commit()
                        #c.execute("Select *from user")
                        r=c.fetchall()
                        if r:
                            for i in r:
                                print("Welcome"+i[1]+"you have registered")
                                window1.Close()
                                break"""

# %%
"""def login():
                    with conn:
                        find_user=("SELECT * FROM User WHERE Username=? AND Email=? AND Password=?")
                        #find_user1=("SELECT * FROM User WHERE Email=?,Password=?")
                        c.execute(find_user,([(name),(email),(password)]))
                        #c.execute(find_user1,[(email),(password)])
                        #conn.commit()
                        results=c.fetchall()
                
                        if results:
                            for i in results:
                                print("Welcome"+i[1])
                                break
                        else:
                            print("Username and password not recognised")
                            again=input("Do you want to try again?y/n ")
                            if again.lower()=="n":
                                print("Goodbye")
                                speak("Goodbye")
                                time.sleep(.1)
                            elif again.lower()=="y":
                                print("Please enter username and password ")
                                time.sleep(.1)"""

# %%
if(T>=1):
            Sound()
        elif(s==0):
            Alarm()

# %%
if(event=="Register_for_Quiz"):
    layout0=[
        [sg.Text("User Registration",size=(15,3))],
        [sg.Text('User Name', size=(15, 1)), sg.InputText('',key="name")],
        [sg.Text('First_Name', size=(15, 1)), sg.InputText('',key="first_name")],
        [sg.Text('Last_Name', size=(15, 1)), sg.InputText('',key="last_name")],
        [sg.Text('Email', size=(15, 1)), sg.InputText('',key="email")],
        [sg.Text('Password', size=(15, 1)), sg.InputText('',key="password")],
        [sg.Button("Submit"), sg.Button("Exit")] 
    ]

    window0= sg.Window('Registration_For_Quiz_Application').Layout(layout0)
    while True:
        event,values=window0.Read()
        print("event= ", event,"values=",values)
        if(event=="Submit"):
            def insert_user(u):
                with conn:
                    c.execute("INSERT INTO user VALUES (name,first_name,last_name,email,password)")
                    conn.commit()
                    c.execute("Select *from user")
                    print(c.fetchall())
            continue
        elif(event is None or event=="Exit"):  
            break

# %%
elif(event=="Login_in_Quiz"):                        
    layout1=[
        [sg.Text("User Login",size=(15,3))],
        [sg.Text('User Name', size=(15, 1)), sg.InputText('',key="name1")],
        [sg.Text('Email', size=(15, 1)), sg.InputText('',key="email1")],
        [sg.Text('Password', size=(15, 1)), sg.InputText('',key="password1")],
        [sg.Button("Login"), sg.Button("Exit")]
    ]  
    
    window1= sg.Window('Login_For_Quiz_Application').Layout(layout1)
    while True:
        event,values=window1.Read()
        print("event= ", event,"values=",values)
        if(event=="Login"):
            find_user=("SELECT * FROM User WHERE Username=? AND Password=?")
            c.execute(find_user,[("name1"),("password1")])
            conn.commit()
            results=c.fetchall()
                
            if results:
                for i in results:
                    print("Welcome"+i[1])
            else:
                print("Username and password not recognised")
                again=input("Do you want to try again?y/n ")
                if again.lower()=="n":
                    print("Goodbye")
                    time.sleep(1)
                        
        elif(event is None or event=="Exit"):
            break

# %%
import time
import pygame


########################################CODE FOR TIMER SOUND###########################################################    
def Sound():
    pygame.mixer.init()
    pygame.mixer.music.load("tictiksound.mp3")
    pygame.mixer.music.play()
########################################CODE FOR TIMER SOUND###########################################################
def Alarm():
    pygame.mixer.init()
    pygame.mixer.music.load("LoudAlarm.mp3")
    pygame.mixer.music.play()
#########################################CODE FOR TIMER################################################################    
hr=0
min=0
sec=30
for i in range(0,sec+1):
    print(str(hr).zfill(2)+":"+str(min).zfill(2)+":"+str(sec-i).zfill(2))
    Sound()
    time.sleep(1)
    #Alarm()
print("Time is up")
Alarm()
# Out:
# 00:00:30
# 00:00:29
# 00:00:28
# 00:00:27
# 00:00:26
# 00:00:25
# 00:00:24
# 00:00:23
# 00:00:22
# 00:00:21
# 00:00:20
# 00:00:19
# 00:00:18
# 00:00:17
# 00:00:16
# 00:00:15
# 00:00:14
# 00:00:13
# 00:00:12
# 00:00:11
# 00:00:10
# 00:00:09
# 00:00:08
# 00:00:07
# 00:00:06
# 00:00:05
# 00:00:04
# 00:00:03
# 00:00:02
# 00:00:01
# 00:00:00
# Time is up

# %%
    voices=engine.getProperty("voices")
    #print(voices[1].id)
    engine.setProperty("voice",voices[0].id)



    def speak(audio):
        engine.say(audio)
        engine.runAndWait()
########################################CODE FOR GENERATION OF QUIZ####################################################       
    
    
    list_Y=[]    
    Score=0    
    for i in range(10):
        r=np.random.randint(0,30)
        print(r)
        layout1=[
            [sg.Text(str(df.iloc[r,1]),key="Question")],
            [sg.Radio(str(df.iloc[r,2]),"Radio",key="Radio1")],
            [sg.Radio(str(df.iloc[r,3]),"Radio",key="Radio2")],
            [sg.Radio(str(df.iloc[r,4]),"Radio",key="Radio3")],
            [sg.Radio(str(df.iloc[r,5]),"Radio",key="Radio4")],
            [sg.Button("Next")],
            [sg.Button("Lock_Answer")],
            #[sg.Button("Submit")],
            [sg.Button("Quit")]]
        window1 = sg.Window('Quiz_Application').Layout(layout1)
        while True:
            event,values=window1.Read()
            l=values
            print(l)
            print("event= ", event,"values=",values)
            break
        if(event is None or event=="Quit"):
            break
        elif(event=="Lock_Answer"):
            if(l["Radio1"]==True):
                if(df.iloc[r,2]==df.iloc[r,6]):
                    print("Your Answer is correct")
                    Score+=10
                    list_Y.append(Score)
                else:
                    print("Your Answer is Wrong")
                    list_Y.append(0)
    
            elif(l["Radio2"]==True):
                if(df.iloc[r,3]==df.iloc[r,6]):
                    print("Your Answer is correct")
                    Score+=10
                    list_Y.append(Score)
                else:
                    print("Your Answer is Wrong")
                    list_Y.append(0)
    
            elif(l["Radio3"]==True):
                if(df.iloc[r,4]==df.iloc[r,6]):
                    print("Your Answer is correct")
                    Score+=10
                    list_Y.append(Score)
                else:
                    print("Your Answer is Wrong")
                    list_Y.append(0)
                
            elif(l["Radio4"]==True):
                if(df.iloc[r,5]==df.iloc[r,6]):
                    print("Your Answer is correct")
                    Score+=10
                    list_Y.append(Score)
                else:
                    print("Your Answer is Wrong")
                    list_Y.append(0)
            else:
                #print("Your Answer is Wrong")
                print("Correct Answer")
                print(str(df.iloc[r,6]))
            try:
                summary2=wikipedia.summary(str(df.iloc[r,6]),sentences=5)
                print("Correct Answer")
                print(str(df.iloc[r,6]))
                print(summary2)
                #speak(summary2)
            except:
                print("No Page Found on WIKIPEDIA")
                #speak("No Page Found on WIKIPEDIA")
                #summary=wikipedia.summary(str(df.iloc[r,1]),sentences=5)
                #print(str(df.iloc[r,1]))
                #print(summary)
                #speak(summary)    
        
        elif(event=="Next"):
            continue

        
#########################################CODE FOR SUBMIT WINDOW########################################################
    x=np.arange(1,11,1)
    print(x)
    layout2=[
        [sg.Button("Submit")]
    ]
    window2 = sg.Window('Quiz_Application_Submit').Layout(layout2)
    while True:
        event,values=window2.Read()
        print("event= ", event,"values=",values)
        if(event=="Submit"):
            print("Score=",Score)
            x=np.arange(1,11,1)
            y=list_Y
            print(y)
            plt.plot(x,y)
        plt.show()
        
   # print(x)    
#print(list_Y)
