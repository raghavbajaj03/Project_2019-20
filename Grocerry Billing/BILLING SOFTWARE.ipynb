# %%
from tkinter import *
import time
import datetime
import random
from tkinter import messagebox

r =Tk()
r.geometry("1350x750+0+0")
r.title("SHREE ENTERPRISE")
r.configure(background='Grey')

Tops = Frame(r,bg='yellow',bd=20,pady=5,relief=RAISED)
Tops.pack(side=TOP)

lblTitle=Label(Tops,font=('arial',60,'bold'),text='SHREE ENTERPRISE',bd=21,bg='Pink',
                fg='cornsilk',justify=CENTER)
lblTitle.grid(row=0)

Receipt = Frame(r,bg='Red',bd=10,relief=RAISED)
Receipt.pack(side=RIGHT)

Buttons=Frame(Receipt,bg='Red',bd=3,relief=RAISED)
Buttons.pack(side=BOTTOM)

Cal_F=Frame(Receipt,bg='Red',bd=6,relief=RAISED)
Cal_F.pack(side=TOP)

Receipt_F=Frame(Receipt,bg='Red',bd=4,relief=RAISED)
Receipt_F.pack(side=BOTTOM)

MenuFrame = Frame(r,bg='Red',bd=10,relief=RAISED)
MenuFrame.pack(side=LEFT)
Cost_F=Frame(MenuFrame,bg='Red',bd=10)
Cost_F.pack(side=BOTTOM)
#Drinks_F=Frame(MenuFrame,bg='orange',bd=4)
#Drinks_F.pack(side=TOP)


#Drinks_F=Frame(MenuFrame,bg='orange',bd=4,relief=RIDGE)
#Drinks_F.pack(side=LEFT)
Food_F=Frame(MenuFrame,bg='Red',bd=4,relief=FLAT,width=20)
Food_F.pack(side=LEFT)
Food_F1=Frame(MenuFrame,bg='Red',bd=4,relief=FLAT,width=20)
Food_F1.pack(side=RIGHT)


###################################################variables################################################

var1=IntVar()
var2=IntVar()
var3=IntVar()
var4=IntVar()
var5=IntVar()
var6=IntVar()
var7=IntVar()
var8=IntVar()
var9=IntVar()
var10=IntVar()
var11=IntVar()
var12=IntVar()
var13=IntVar()
var14=IntVar()
var15=IntVar()
var16=IntVar()
var17=IntVar()
var18=IntVar()
var19=IntVar()
var20=IntVar()


DateofOrder = StringVar()
Receipt_Ref = StringVar()
PaidGST = StringVar()             #sgst and cgst 
SubTotal = StringVar()
TotalCost = StringVar()
#Cost = StringVar()
#CostofDrinks = StringVar()
Cost=StringVar()
ServiceCharge = StringVar()

text_Input = StringVar()
operator = ""

E_RICE = StringVar()
E_COOKING_OIL = StringVar()
E_TOOTHPASTE = StringVar()
E_SALT = StringVar()
E_RED_CHILLI = StringVar()
E_TURMERIC_POWDER = StringVar()
E_TEA_LEAVES = StringVar()
E_BLACK_SALT = StringVar()

E_ROCK_SALT = StringVar()
E_PULSES = StringVar()
E_COARINDER_LEAVES = StringVar()
E_BEANS = StringVar()
E_FLOUR = StringVar()
E_WHEAT = StringVar()
E_BAJRA = StringVar()
E_MAIZE = StringVar()
E_BLACK_PEPPER = StringVar()
E_ANISE = StringVar()
E_CUMIN = StringVar()
E_SUGAR = StringVar()


E_RICE.set("0")
E_COOKING_OIL.set("0") 
E_TOOTHPASTE.set("0")
E_SALT.set("0")
E_RED_CHILLI.set("0") 
E_TURMERIC_POWDER.set("0") 
E_TEA_LEAVES.set("0")
E_BLACK_SALT.set("0") 

E_ROCK_SALT.set("0") 
E_PULSES.set("0") 
E_COARINDER_LEAVES.set("0") 
E_BEANS.set("0") 
E_FLOUR.set("0")
E_WHEAT.set("0") 
E_BAJRA.set("0")
E_MAIZE.set("0") 
E_BLACK_PEPPER.set("0") 
E_ANISE.set("0") 
E_CUMIN.set("0") 
E_SUGAR.set("0")

DateofOrder.set(time.strftime("%d/%m/%y"))

##########################################Function Declaration####################################################

def iExit():
    iExit=messagebox.askyesno("Exit BILLING System","Confirm if you want to exit")
    if iExit > 0:
        r.destroy()
        return

def Reset():
    PaidGST.set("")
    SubTotal.set("")
    TotalCost.set("")
    #Cost.set("")
    #CostofDrinks.set("")
    Cost.set("")
    #ServiceCharge.set("")
    txtReceipt.delete("1.0",END)


    E_RICE.set("0")
    E_COOKING_OIL.set("0") 
    E_TOOTHPASTE.set("0")
    E_SALT.set("0")
    E_RED_CHILLI.set("0") 
    E_TURMERIC_POWDER.set("0") 
    E_TEA_LEAVES.set("0")
    E_BLACK_SALT.set("0") 

    E_ROCK_SALT.set("0") 
    E_PULSES.set("0") 
    E_COARINDER_LEAVES.set("0") 
    E_BEANS.set("0")
    E_FLOUR.set("0")
    E_WHEAT.set("0") 
    E_BAJRA.set("0")
    E_MAIZE.set("0")
    E_BLACK_PEPPER.set("0")
    E_ANISE.set("0")
    E_CUMIN.set("0")
    E_SUGAR.set("0")

    var1.set(0)
    var2.set(0)
    var3.set(0)
    var4.set(0)
    var5.set(0)
    var6.set(0)
    var7.set(0)
    var8.set(0)
    var9.set(0)
    var10.set(0)
    var11.set(0)
    var12.set(0)
    var13.set(0)
    var14.set(0)
    var15.set(0)
    var16.set(0)
    var17.set(0)
    var18.set(0)
    var19.set(0)
    var20.set(0)



    txtRICE.configure(state=DISABLED)
    txtCOOKING_OIL.configure(state=DISABLED)
    txtTOOTHPASTE.configure(state=DISABLED)
    txtSALT.configure(state=DISABLED)
    txtRED_CHILLI.configure(state=DISABLED)
    txtTURMERIC_POWDER.configure(state=DISABLED)
    txtTEA_LEAVES.configure(state=DISABLED)
    txtBLACK_SALT.configure(state=DISABLED)
    txtROCK_SALT.configure(state=DISABLED)
    txtPULSES.configure(state=DISABLED)
    txtCOARINDER_LEAVES.configure(state=DISABLED)
    txtBEANS.configure(state=DISABLED)
    txtFLOUR.configure(state=DISABLED)
    txtWHEAT.configure(state=DISABLED)
    txtBAJRA.configure(state=DISABLED)
    txtMAIZE.configure(state=DISABLED)
    txtBLACK_PEPPER.configure(state=DISABLED) 
    txtANISE.configure(state=DISABLED)
    txtCUMIN.configure(state=DISABLED)
    txtSUGAR.configure(state=DISABLED)

def CostofItem2():
    TotalCost.set("0")
    
def CostofItem():
    Item1=float(E_RICE.get())
    Item2=float(E_COOKING_OIL.get())
    Item3=float(E_TOOTHPASTE.get())
    Item4=float(E_SALT.get())
    Item5=float(E_RED_CHILLI.get())
    Item6=float(E_TURMERIC_POWDER.get())
    Item7=float(E_TEA_LEAVES.get())
    Item8=float(E_BLACK_SALT.get())

    Item9=float(E_ROCK_SALT.get())
    Item10=float(E_PULSES.get())
    Item11=float(E_COARINDER_LEAVES.get())
    Item12=float(E_BEANS.get())
    Item13=float(E_FLOUR.get())
    Item14=float(E_WHEAT.get())
    Item15=float(E_BAJRA.get())
    Item16=float(E_MAIZE.get())
    Item17=float(E_BLACK_PEPPER.get())
    Item18=float(E_ANISE.get())
    Item19=float(E_CUMIN.get())
    Item20=float(E_SUGAR.get())

    Cost1 =(Item1 * 65) + (Item2 * 70) + (Item3 * 40) + (Item4 * 20) + (Item5 * 70) + (Item6 * 90) + (Item7 * 240) 
    + (Item8 * 10)+(Item9 * 20) + (Item10 * 80) + (Item11 *65) + (Item12 * 50) + (Item13 * 85) + (Item14 * 50) 
    + (Item15 * 65) + (Item16 * 65)+ (Item17 * 500)+ (Item18 * 50)+ (Item19 * 65)+ (Item20 * 40)
    
    #Cost1=  "Rs",str('%.2f'%(Cost1))
    Cost.set(Cost1)
    SC = "Rs",str('%.2f'%(1.59))
    ServiceCharge.set(SC)

    SubTotalofITEMS = "Rs",str('%.2f'%(Cost1+ 1.59))
    SubTotal.set(SubTotalofITEMS)

    Gst= "Rs",str('%.2f'%((Cost1+ 1.59) * 0.15))
    PaidGST.set(Gst)

    TT=((Cost1 + 1.59) * 0.15)
    TC="Rs",str('%.2f'%(Cost1+ 1.59 + TT))
    TotalCost.set(TC)
    
    print("Cost1= ",Cost1)
    print("Cost= ",Cost)
    print("SC= ",SC)
    print("Sub Total= ",SubTotalofITEMS)


def chkRICE():
    if(var1.get() == 1):
        txtRICE.configure(state = NORMAL)
        txtRICE.focus()
        txtRICE.delete('0',END)
        E_RICE.set("")
    elif(var1.get() == 0):
        txtRICE.configure(state = DISABLED)
        E_RICE.set("0")

def chkCOOKING_OIL():
    if(var2.get() == 1):
        txtCOOKING_OIL.configure(state = NORMAL)
        txtCOOKING_OIL.focus()
        txtCOOKING_OIL.delete('0',END)
        E_COOKING_OIL.set("")
    elif(var2.get() == 0):
        txtCOOKING_OIL.configure(state = DISABLED)
        E_COOKING_OIL.set("0")

def chk_TOOTHPASTE():
    if(var3.get() == 1):
        txtTOOTHPASTE.configure(state = NORMAL)
        txtTOOTHPASTE.delete('0',END)
        txtTOOTHPASTE.focus()
    elif(var3.get() == 0):
        txtTOOTHPASTE.configure(state = DISABLED)
        E_TOOTHPASTE.set("0")

def chk_SALT():
    if(var4.get() == 1):
        txtSALT.configure(state = NORMAL)
        txtSALT.delete('0',END)
        txtSALT.focus()
    elif(var4.get() == 0):
        txtSALT.configure(state = DISABLED)
        E_SALT.set("0")

def chk_RED_CHILLI():
    if(var5.get() == 1):
        txtRED_CHILLI.configure(state = NORMAL)
        txtRED_CHILLI.delete('0',END)
        txtRED_CHILLI.focus()
    elif(var5.get() == 0):
        txtRED_CHILLI.configure(state = DISABLED)
        E_RED_CHILLI.set("0")

def chk_TURMERIC_POWDER():
    if(var6.get() == 1):
        txtTURMERIC_POWDER.configure(state = NORMAL)
        txtTURMERIC_POWDER.delete('0',END)
        txtTURMERIC_POWDER.focus()
    elif(var6.get() == 0):
        txtTURMERIC_POWDER.configure(state = DISABLED)
        E_TURMERIC_POWDER.set("0")

def chk_TEA_LEAVES():
    if(var7.get() == 1):
        txtTEA_LEAVES.configure(state = NORMAL)
        txtTEA_LEAVES.delete('0',END)
        txtTEA_LEAVES.focus()
    elif(var7.get() == 0):
        txtTEA_LEAVES.configure(state = DISABLED)
        E_TEA_LEAVES.set("0")

def chk_BLACK_SALT():
    if(var8.get() == 1):
        txtBLACK_SALT.configure(state = NORMAL)
        txtBLACK_SALT.delete('0',END)
        txtBLACK_SALT.focus()
    elif(var8.get() == 0):
        txtBLACK_SALT.configure(state = DISABLED)
        E_BLACK_SALT.set("0")

def chk_ROCK_SALT():
    if(var9.get() == 1):
        txtROCK_SALT.configure(state = NORMAL)
        txtROCK_SALT.delete('0',END)
        txtROCK_SALT.focus()
    elif(var9.get() == 0):
        txtROCK_SALT.configure(state = DISABLED)
        E_ROCK_SALT.set("0")

def chk_PULSES():
    if(var10.get() == 1):
        txtPULSES.configure(state = NORMAL)
        txtPULSES.delete('0',END)
        txtPULSES.focus()
    elif(var10.get() == 0):
        txtPULSES.configure(state = DISABLED)
        E_PULSES.set("0")

def chk_COARINDER_LEAVES():
    if(var11.get() == 1):
        txtCOARINDER_LEAVES.configure(state = NORMAL)
        txtCOARINDER_LEAVES.delete('0',END)
        txtCOARINDER_LEAVES.focus()
    elif(var11.get() == 0):
        txtCOARINDER_LEAVES.configure(state = DISABLED)
        E_COARINDER_LEAVES.set("0")

def chk_BEANS():
    if(var12.get() == 1):
        txtBEANS.configure(state = NORMAL)
        txtBEANS.delete('0',END)
        txtBEANS.focus()
    elif(var12.get() == 0):
        txtBEANS.configure(state = DISABLED)
        E_BEANS.set("0")

def chk_FLOUR():
    if(var13.get() == 1):
        txtFLOUR.configure(state = NORMAL)
        txtFLOUR.delete('0',END)
        txtFLOUR.focus()
    elif(var13.get() == 0):
        txtFLOUR.configure(state = DISABLED)
        E_FLOUR.set("0")

def chk_WHEAT():
    if(var14.get() == 1):
        txtWHEAT.configure(state = NORMAL)
        txtWHEAT.delete('0',END)
        txtWHEAT.focus()
    elif(var14.get() == 0):
        txtWHEAT.configure(state = DISABLED)
        E_WHEAT.set("0")

def chk_BAJRA():
    if(var15.get() == 1):
        txtBAJRA.configure(state = NORMAL)
        txtBAJRA.delete('0',END)
        txtBAJRA.focus()
    elif(var15.get() == 0):
        txtBAJRA.configure(state = DISABLED)
        E_BAJRA.set("0")

def chk_MAIZE():
    if(var16.get() == 1):
        txtMAIZE.configure(state = NORMAL)
        txtMAIZE.delete('0',END)
        txtMAIZE.focus()
    elif(var16.get() == 0):
        txtMAIZE.configure(state = DISABLED)
        E_MAIZE.set("0")
def chk_BLACK_PEPPER():
    if(var17.get() == 1):
        txtBLACK_PEPPER.configure(state = NORMAL)
        txtBLACK_PEPPER.delete('0',END)
        txtBLACK_PEPPER.focus()
    elif(var17.get() == 0):
        txtBLACK_PEPPER.configure(state = DISABLED)
        E_BLACK_PEPPER.set("0")
def chk_ANISE():
    if(var18.get() == 1):
        txtANISE.configure(state = NORMAL)
        txtANISE.delete('0',END)
        txtANISE.focus()
    elif(var18.get() == 0):
        txtANISE.configure(state = DISABLED)
        E_ANISE.set("0")
def chk_CUMIN():
    if(var19.get() == 1):
        txtCUMIN.configure(state = NORMAL)
        txtCUMIN.delete('0',END)
        txtCUMIN.focus()
    elif(var19.get() == 0):
        txtCUMIN.configure(state = DISABLED)
        E_CUMIN.set("0")        
def chk_SUGAR():
    if(var20.get() == 1):
        txtSUGAR.configure(state = NORMAL)
        txtSUGAR.delete('0',END)
        txtSUGAR.focus()
    elif(var20.get() == 0):
        txtSUGAR.configure(state = DISABLED)
        E_SUGAR.set("0")        

def Receipt():
    txtReceipt.delete("1.0",END)
    x=random.randint(10908,500876)
    randomRef= str(x)
    Receipt_Ref.set("Bill"+ randomRef)


    txtReceipt.insert(END,'Receipt Ref:\t\t\t'+Receipt_Ref.get() +'\t'+ DateofOrder.get() +'\n')
    txtReceipt.insert(END,'Items\t\t\t\t'+"Cost of Items \n")
    txtReceipt.insert(END,'RICE:\t\t\t\t\t' + E_RICE.get() +'\n')
    txtReceipt.insert(END,'COOKING_OIL:\t\t\t\t\t'+ E_COOKING_OIL.get()+'\n')
    txtReceipt.insert(END,'TOOTHPASTE:\t\t\t\t\t'+ E_TOOTHPASTE.get()+'\n')
    txtReceipt.insert(END,'SALT:\t\t\t\t\t'+ E_SALT.get()+'\n')
    txtReceipt.insert(END,'RED_CHILLI:\t\t\t\t\t'+ E_RED_CHILLI.get()+'\n')
    txtReceipt.insert(END,'TURMERIC_POWDER:\t\t\t\t\t'+ E_TURMERIC_POWDER.get()+'\n')
    txtReceipt.insert(END,'TEA_LEAVES:\t\t\t\t\t'+ E_TEA_LEAVES.get()+'\n')
    txtReceipt.insert(END,'BLACK_SALT:\t\t\t\t\t'+ E_BLACK_SALT.get()+'\n')
    txtReceipt.insert(END,'ROCK_SALT:\t\t\t\t\t'+ E_ROCK_SALT.get()+'\n')
    txtReceipt.insert(END,'PULSES:\t\t\t\t\t'+ E_PULSES.get()+'\n')
    txtReceipt.insert(END,'COARINDER_LEAVES:\t\t\t\t\t'+ E_COARINDER_LEAVES.get()+'\n')
    txtReceipt.insert(END,'BEANS:\t\t\t\t\t'+ E_BEANS.get()+'\n')
    txtReceipt.insert(END,'FLOUR:\t\t\t\t\t'+ E_FLOUR.get()+'\n')
    txtReceipt.insert(END,'WHEAT:\t\t\t\t\t'+ E_WHEAT.get()+'\n')
    txtReceipt.insert(END,'BAJRA:\t\t\t\t\t'+ E_BAJRA.get()+'\n')
    txtReceipt.insert(END,'MAIZE:\t\t\t\t\t'+ E_MAIZE.get()+'\n')
    txtReceipt.insert(END,'BLACK_PEPPER:\t\t\t\t\t'+ E_BLACK_PEPPER.get()+'\n')
    txtReceipt.insert(END,'ANISE:\t\t\t\t\t'+ E_ANISE.get()+'\n')
    txtReceipt.insert(END,'CUMIN:\t\t\t\t\t'+ E_CUMIN.get()+'\n')
    txtReceipt.insert(END,'SUGAR:\t\t\t\t\t'+ E_SUGAR.get()+'\n')
    txtReceipt.insert(END,'Cost:\t\t\t\t\t'+ Cost.get()+'\n GST Paid:\t\t\t\t'+PaidGST.get()+"\n")
    txtReceipt.insert(END,'\nSubTotal:\t\t\t\t'+str(SubTotal.get())+"\n")
    txtReceipt.insert(END,'Service Charge:\t\t\t\t'+ ServiceCharge.get()+'\nTotal Cost:\t\t\t\t'+str(TotalCost.get()))
###############################################################################################################
#############################################################################################################
RICE=Checkbutton(Food_F,text='RICE',variable=var1,onvalue=1,offvalue=0,font=('arial',18,'bold'),
                    bg='orange',command=chkRICE).grid(row=0,sticky=W)
COOKING_OIL=Checkbutton(Food_F,text='COOKING_OIL',variable=var2,onvalue=1,offvalue=0,font=('arial',18,'bold'),
                    bg='orange',command=chkCOOKING_OIL).grid(row=1,sticky=W)
TOOTHPASTE=Checkbutton(Food_F,text='TOOTHPASTE',variable=var3,onvalue=1,offvalue=0,font=('arial',18,'bold'),
                    bg='orange',command=chk_TOOTHPASTE).grid(row=2,sticky=W)
SALT=Checkbutton(Food_F,text='SALT',variable=var4,onvalue=1,offvalue=0,font=('arial',18,'bold'),
                    bg='orange',command=chk_SALT).grid(row=3,sticky=W)
RED_CHILLI=Checkbutton(Food_F,text='RED_CHILLI',variable=var5,onvalue=1,offvalue=0,font=('arial',18,'bold'),
                    bg='orange',command=chk_RED_CHILLI).grid(row=4,sticky=W)
TURMERIC_POWDER=Checkbutton(Food_F,text='TURMERIC_POWDER',variable=var6,onvalue=1,offvalue=0,font=('arial',18,'bold'),
                    bg='orange',command=chk_TURMERIC_POWDER).grid(row=5,sticky=W)
TEA_LEAVES=Checkbutton(Food_F,text='TEA_LEAVES',variable=var7,onvalue=1,offvalue=0,font=('arial',18,'bold'),
                    bg='orange',command=chk_TEA_LEAVES).grid(row=6,sticky=W)
BLACK_SALT=Checkbutton(Food_F,text='BLACK_SALT',variable=var8,onvalue=1,offvalue=0,font=('arial',18,'bold'),
                    bg='orange',command=chk_BLACK_SALT).grid(row=7,sticky=W)
ROCK_SALT = Checkbutton(Food_F,text="ROCK_SALT\t\t\t ",variable=var9,onvalue = 1, offvalue=0,
                        font=('arial',16,'bold'),bg='orange',command=chk_ROCK_SALT).grid(row=8,sticky=W)
PULSES = Checkbutton(Food_F,text="PULSES",variable=var10,onvalue = 1, offvalue=0,
                        font=('arial',16,'bold'),bg='orange',command=chk_PULSES).grid(row=9,sticky=W)



COARINDER_LEAVES = Checkbutton(Food_F1,text="COARINDER_LEAVES ",variable=var11,onvalue = 1, offvalue=0,
                        font=('arial',16,'bold'),bg='orange',command=chk_COARINDER_LEAVES).grid(row=0,sticky=W)
BEANS = Checkbutton(Food_F1,text="BEANS",variable=var12,onvalue = 1, offvalue=0,
                        font=('arial',16,'bold'),bg='orange',command=chk_BEANS).grid(row=1,sticky=W)
FLOUR = Checkbutton(Food_F1,text="FLOUR ",variable=var13,onvalue = 1, offvalue=0,
                        font=('arial',16,'bold'),bg='orange',command=chk_FLOUR).grid(row=2,sticky=W)
WHEAT = Checkbutton(Food_F1,text="WHEAT ",variable=var14,onvalue = 1, offvalue=0,
                        font=('arial',16,'bold'),bg='orange',command=chk_WHEAT).grid(row=3,sticky=W)
BAJRA = Checkbutton(Food_F1,text="BAJRA ",variable=var15,onvalue = 1, offvalue=0,
                        font=('arial',16,'bold'),bg='orange',command=chk_BAJRA).grid(row=4,sticky=W)
MAIZE = Checkbutton(Food_F1,text="MAIZE ",variable=var16,onvalue = 1, offvalue=0,
                        font=('arial',16,'bold'),bg='orange',command=chk_MAIZE).grid(row=5,sticky=W)
BLACK_PEPPER = Checkbutton(Food_F1,text="BLACK_PEPPER",variable=var17,onvalue = 1, offvalue=0,
                        font=('arial',16,'bold'),bg='orange',command=chk_BLACK_PEPPER).grid(row=6,sticky=W)
ANISE = Checkbutton(Food_F1,text="ANISE",variable=var18,onvalue = 1, offvalue=0,
                        font=('arial',16,'bold'),bg='orange',command=chk_ANISE).grid(row=7,sticky=W)
CUMIN = Checkbutton(Food_F1,text="CUMIN ",variable=var19,onvalue = 1, offvalue=0,
                        font=('arial',16,'bold'),bg='orange',command=chk_CUMIN).grid(row=8,sticky=W)
SUGAR = Checkbutton(Food_F1,text="SUGAR",variable=var20,onvalue = 1, offvalue=0,
                        font=('arial',16,'bold'),bg='orange',command=chk_SUGAR).grid(row=9,sticky=W)
                      
#####################################################################################################################################                      
                      
                      
txtRICE = Entry(Food_F,font=('arial',16,'bold'),bd=8,width=6,justify=LEFT,state=DISABLED
                        ,textvariable=E_RICE)
txtRICE.grid(row=0,column=1)

txtCOOKING_OIL = Entry(Food_F,font=('arial',16,'bold'),bd=8,width=6,justify=LEFT,state=DISABLED
                        ,textvariable=E_COOKING_OIL)
txtCOOKING_OIL.grid(row=1,column=1)

txtTOOTHPASTE = Entry(Food_F,font=('arial',16,'bold'),bd=8,width=6,justify=LEFT,state=DISABLED
                        ,textvariable=E_TOOTHPASTE)
txtTOOTHPASTE.grid(row=2,column=1)

txtSALT= Entry(Food_F,font=('arial',16,'bold'),bd=8,width=6,justify=LEFT,state=DISABLED
                        ,textvariable=E_SALT)
txtSALT.grid(row=3,column=1)

txtRED_CHILLI = Entry(Food_F,font=('arial',16,'bold'),bd=8,width=6,justify=LEFT,state=DISABLED
                        ,textvariable=E_RED_CHILLI)
txtRED_CHILLI.grid(row=4,column=1)

txtTURMERIC_POWDER = Entry(Food_F,font=('arial',16,'bold'),bd=8,width=6,justify=LEFT,state=DISABLED
                        ,textvariable=E_TURMERIC_POWDER)
txtTURMERIC_POWDER.grid(row=5,column=1)

txtTEA_LEAVES = Entry(Food_F,font=('arial',16,'bold'),bd=8,width=6,justify=LEFT,state=DISABLED
                        ,textvariable=E_TEA_LEAVES)
txtTEA_LEAVES.grid(row=6,column=1)

txtBLACK_SALT = Entry(Food_F,font=('arial',16,'bold'),bd=8,width=6,justify=LEFT,state=DISABLED
                        ,textvariable=E_BLACK_SALT)
txtBLACK_SALT.grid(row=7,column=1)

txtROCK_SALT=Entry(Food_F,font=('arial',16,'bold'),bd=8,width=6,justify=LEFT,state=DISABLED,
                        textvariable=E_ROCK_SALT)
txtROCK_SALT.grid(row=8,column=1)

txtPULSES=Entry(Food_F,font=('arial',16,'bold'),bd=8,width=6,justify=LEFT,state=DISABLED,
                        textvariable=E_PULSES)
txtPULSES.grid(row=9,column=1)




txtCOARINDER_LEAVES=Entry(Food_F1,font=('arial',16,'bold'),bd=8,width=6,justify=LEFT,state=DISABLED,
                        textvariable=E_COARINDER_LEAVES)
txtCOARINDER_LEAVES.grid(row=0,column=1)

txtBEANS=Entry(Food_F1,font=('arial',16,'bold'),bd=8,width=6,justify=LEFT,state=DISABLED,
                        textvariable=E_BEANS)
txtBEANS.grid(row=1,column=1)

txtFLOUR=Entry(Food_F1,font=('arial',16,'bold'),bd=8,width=6,justify=LEFT,state=DISABLED,
                        textvariable=E_FLOUR)
txtFLOUR.grid(row=2,column=1)

txtWHEAT=Entry(Food_F1,font=('arial',16,'bold'),bd=8,width=6,justify=LEFT,state=DISABLED,
                        textvariable=E_WHEAT)
txtWHEAT.grid(row=3,column=1)

txtBAJRA=Entry(Food_F1,font=('arial',16,'bold'),bd=8,width=6,justify=LEFT,state=DISABLED,
                        textvariable=E_BAJRA)
txtBAJRA.grid(row=4,column=1)

txtMAIZE=Entry(Food_F1,font=('arial',16,'bold'),bd=8,width=6,justify=LEFT,state=DISABLED,
                        textvariable=E_MAIZE)
txtMAIZE.grid(row=5,column=1)
                                                                                                     
txtBLACK_PEPPER=Entry(Food_F1,font=('arial',16,'bold'),bd=8,width=6,justify=LEFT,state=DISABLED,
                        textvariable=E_BLACK_PEPPER)
txtBLACK_PEPPER.grid(row=6,column=1)

txtANISE=Entry(Food_F1,font=('arial',16,'bold'),bd=8,width=6,justify=LEFT,state=DISABLED,
                        textvariable=E_ANISE)
txtANISE.grid(row=7,column=1)  
                
txtCUMIN=Entry(Food_F1,font=('arial',16,'bold'),bd=8,width=6,justify=LEFT,state=DISABLED,
                        textvariable=E_CUMIN)
txtCUMIN.grid(row=8,column=1)
                                                                                                     
txtSUGAR=Entry(Food_F1,font=('arial',16,'bold'),bd=8,width=6,justify=LEFT,state=DISABLED,
                        textvariable=E_SUGAR)
txtSUGAR.grid(row=9,column=1)
###########################################ToTal Cost################################################################################
lblCost=Label(Cost_F,font=('arial',14,'bold'),text='Cost',bg='orange',
                    fg='black',justify=CENTER)
lblCost.grid(row=0,column=0,sticky=W)
txtCost=Entry(Cost_F,bg='white',bd=7,font=('arial',14,'bold'),
                        insertwidth=2,justify=RIGHT,textvariable=Cost)
txtCost.grid(row=0,column=1)

lblCost=Label(Cost_F,font=('arial',14,'bold'),text='Cost of Foods  ',bg='orange',
                    fg='black',justify=CENTER)
lblCost.grid(row=1,column=0,sticky=W)
txtCost=Entry(Cost_F,bg='white',bd=7,font=('arial',14,'bold'),
                        insertwidth=2,justify=RIGHT,textvariable=Cost)
txtCost.grid(row=1,column=1)

lblServiceCharge=Label(Cost_F,font=('arial',14,'bold'),text='Service Charge',bg='orange',
                        fg='black',justify=CENTER)
lblServiceCharge.grid(row=2,column=0,sticky=W)
txtServiceCharge=Entry(Cost_F,bg='white',bd=7,font=('arial',14,'bold'),
                        insertwidth=2,justify=RIGHT,textvariable=ServiceCharge)
txtServiceCharge.grid(row=2,column=1)
###########################################################Payment information###################################################

lblPaidGST=Label(Cost_F,font=('arial',14,'bold'),text='Paid GST',bg='orange',bd=7,fg='black',justify=CENTER)
lblPaidGST.grid(row=0,column=2,sticky=W)

txtPaidGST=Entry(Cost_F,bg='white',bd=7,font=('arial',14,'bold'),insertwidth=2,justify=RIGHT,textvariable=PaidGST)
txtPaidGST.grid(row=0,column=3)

lblSubTotal=Label(Cost_F,font=('arial',14,'bold'),text='Sub Total',bg='orange',bd=7,fg='black',justify=CENTER)
lblSubTotal.grid(row=1,column=2,sticky=W)

txtSubTotal=Entry(Cost_F,bg='white',bd=7,font=('arial',14,'bold'),insertwidth=2,justify=RIGHT,textvariable=SubTotal)
txtSubTotal.grid(row=1,column=3)

lblTotalCost=Label(Cost_F,font=('arial',14,'bold'),text='Total',bg='orange',bd=7,fg='black',justify=CENTER)
lblTotalCost.grid(row=2,column=2,sticky=W)

txtTotalCost=Entry(Cost_F,bg='white',bd=7,font=('arial',14,'bold'),insertwidth=2,justify=RIGHT,textvariable=TotalCost)
txtTotalCost.grid(row=2,column=3)

#############################################RECEIPT###############################################################################
txtReceipt=Text(Receipt_F,width=46,height=12,bg='white',bd=4,font=('arial',12,'bold'))
txtReceipt.grid(row=0,column=0)


###########################################BUTTONS################################################################################
btnTotal=Button(Buttons,padx=16,pady=1,bd=7,fg='black',font=('arial',16,'bold'),width=4,text='Total',
                        bg='orange',command=CostofItem).grid(row=0,column=0)
btnReceipt=Button(Buttons,padx=16,pady=1,bd=7,fg='black',font=('arial',16,'bold'),width=4,text='Receipt',
                        bg='orange',command=Receipt).grid(row=0,column=1)
btnReset=Button(Buttons,padx=16,pady=1,bd=7,fg='black',font=('arial',16,'bold'),width=4,text='Reset',
                        bg='orange',command=Reset).grid(row=0,column=2)
btnExit=Button(Buttons,padx=16,pady=1,bd=7,fg='black',font=('arial',16,'bold'),width=4,text='Exit',
                        bg='orange',command=iExit).grid(row=0,column=3)

###################################Calculator Display################################################################################


r.mainloop()

# %% [markdown]
# ## Library software (I,H,Y)

# %%
#PYTHON MODULE :MENULIB(LIBRARY MANAGEMENT SYSTEM)
import Book
import Member
import issue
def MenuBook():
    while True:
        Book.clrscreen()
        print("\t\t\t Book Record Management\n")
        print("==============================================================")
        print("1. Add Book Record ")
        print("2. Display Book Records ")
        print("3. Search Book Record ")
        print("4. Delete Book Record ")
        print("5. Update Book Record ")
        print("6. Return to Main Menu ")
        print("===============================================================")
        choice=int(input("Enter Choice between 1 to 5-------> : "))
        if choice==1:
            Book.insertData()
        elif choice==2:
            Book.display()
        elif choice==3:
            Book.SearchBookRec()
        elif choice==4:
            Book.deleteBook()
        elif choice==5:
            print("No such Function")
        elif choice==6:             
            return
        else:
             print("Wrong Choice......Enter Your Choice again")
x=input("Enter any key to continue")

#----------------------------------------------------------------------------------------
def MenuMember():
    while True:
        Book.clrscreen()
        print("\t\t\t Member Record Management\n")
        print("==============================================================")
        print("1. Add Member Record ")
        print("2. Display Member Records ")
        print("3. Search Member Record ")
        print("4. Delete Member Record ")
        print("5. Update Book Record ")
        print("6. Return to Main Menu ")
        print("===============================================================")
        choice=int(input("Enter Choice between 1 to 5-------> : "))
        if choice==1:
            Member.insertData()
        elif choice==2:
            Member.display()
        elif choice==3:
            Member.SearchMember()
        elif choice==4:
            Member.deleteMember()
        elif choice==5:
            print("No such Function")
        elif choice==6:
            return
        else:
            print("Wrong Choice......Enter Your Choice again")
            x=input("Enter any key to continue")
#----------------------------------------------------------------------------------------
def MenuIssueReturn():
     while True:
        Book.clrscreen()
        print("\t\t\t Member Record Management\n")
        print("==============================================================")
        print("1. Issue Book ")
        print("2. Display Issued Book Records ")
        print("3. Return Issued Book ")
        print("4. Return to Main Menu ")
        print("===============================================================")
        choice=int(input("Enter Choice between 1 to 5-------> : "))
        if choice==1:
            issue.issueBookData()
        elif choice==2:
            issue.ShowIssuedBooks()
        elif choice==3:
            issue.returnBook()
        elif choice==4:
            return
        else:
            print("Wrong Choice......Enter Your Choice again")
            x=input("Enter any key to continue")
#MODULE : LIBRARY MANAGEMENT
import MenuLib
import Book
import issue
while True:
    Book.clrscreen()
    print("\t\t\t Library Management\n")
    print("==============================================================")
    print("1. Book Management ")
    print("2. Members Management s ")
    print("3. Issue/Return Book ")
    print("5. Exit ")
    print("===============================================================")
    choice=int(input("Enter Choice between 1 to 4-------> : "))
    if choice==1:
        MenuLib.MenuBook()
    elif choice==2:
        MenuLib.MenuMember()
    elif choice==3:
        MenuLib.MenuIssueReturn()
    elif choice==4:
        break
    else:
        print("Wrong Choice......Enter Your Choice again")
        x=input("Enter any key to continue")
# PYTHON MODULE : BOOK
import mysql.connector
from mysql.connector import errorcode
from datetime import date, datetime, timedelta
from mysql.connector import (connection)
import os
import platform
def clrscreen():
     if platform.system()=="Windows":
        print(os.system("cls"))

def display():
    try:
        os.system('cls')
        cnx = connection.MySQLConnection(user='root', password='mysql',
               host='localhost',
               database='LIbrary')
        Cursor = cnx.cursor()
        query = ("SELECT * FROM BookRecord")
        Cursor.execute(query)
        for (Bno,Bname,Author,price,publ,qty,d_o_purchase) in Cursor:
            print("==============================================================")
            print("Book Code : ",Bno)
            print("Book Name : ",Bname)
            print("Author of Book : ",Author)
            print("Price of Book : ",price)
            print("Publisher : ",publ)
            print("Total Quantity in Hand : ",qty)
            print("Purchased On : ",d_o_purchase)
            print("===============================================================")
        Cursor.close()
        cnx.close()
        print("You have done it!!!!!!")
    except mysql.connector.Error as err:
        if err.errno == errorcode.ER_ACCESS_DENIED_ERROR:
             print("Something is wrong with your user name or password")
        elif err.errno == errorcode.ER_BAD_DB_ERROR:
             print("Database does not exist")
        else:
             print(err)
        '''else:
            cnx.close()'''

def insertData():
    try:
        cnx = connection.MySQLConnection(user='root',
                         password='mysql',
                         host='127.0.0.1',
                         database='Library')
        Cursor = cnx.cursor()
        
        
        bno=input("Enter Book Code : ") 
        bname=input("Enter Book Name : ")
        Auth=input("Enter Book Author's Name : ")
        price=int(input("Enter Book Price : "))
        publ=input("Enter Publisher of Book : ")
        qty=int(input("Enter Quantity purchased : "))
        print("Enter Date of Purchase (Date/MOnth and Year seperately: ")
        DD=int(input("Enter Date : "))
        MM=int(input("Enter Month : "))
        YY=int(input("Enter Year : "))
        Qry = ("INSERT INTO BookRecord "\
               "VALUES (%s, %s, %s, %s, %s, %s, %s)")
        data = (bno,bname,Auth,price,publ,qty,date(YY,MM,DD))
        Cursor.execute(Qry,data)
       # Make sure data is committed to the database
        cnx.commit()     
        Cursor.close()
        cnx.close()
        print("Record Inserted..............")
    except mysql.connector.Error as err:
        if err.errno == errorcode.ER_ACCESS_DENIED_ERROR:
            print("Something is wrong with your user name or password")
        elif err.errno == errorcode.ER_BAD_DB_ERROR:
            print("Database does not exist")
        else:
            print(err)

        cnx.close()
        
        
        
        
def deleteBook():
    try:
        cnx = connection.MySQLConnection(user='root',
                         password='mysql',
                         host='127.0.0.1',
                         database='Library')
        Cursor = cnx.cursor()
        
        
        bno=input("Enter Book Code of Book to be deleted from the Library : ")

        Qry =("""DELETE FROM BookRecord WHERE BNO = %s""")
        del_rec=(bno,)
        Cursor.execute(Qry,del_rec)

         # Make sure data is committed to the database
        cnx.commit()
        Cursor.close()
        cnx.close()
        print(Cursor.rowcount,"Record(s) Deleted Successfully.............")
    except mysql.connector.Error as err:
        if err.errno == errorcode.ER_ACCESS_DENIED_ERROR:
                print("Something is wrong with your user name or password")
        elif err.errno == errorcode.ER_BAD_DB_ERROR:
                print("Database does not exist")
        else:
                print(err)

        cnx.close()

def SearchBookRec():
    try:
        cnx = connection.MySQLConnection(user='root',
                         password='mysql',
                         host='127.0.0.1',
                         database='Library')
        Cursor = cnx.cursor()
        
        
        bno=input("Enter Book No to be Searched from the Library : ")
        query = ("SELECT * FROM BookRecord where BNo = %s ")

        rec_srch=(bno,)
        Cursor.execute(query,rec_srch)

        Rec_count=0

        for (Bno,Bname,Author,price,publ,qty,d_o_purchase) in Cursor:
            Rec_count+=1
            print("==============================================================")
            print("Book Code : ",Bno)
            print("Book Name : ",Bname)
            print("Author of Book : ",Author)
            print("Price of Book : ",price)
            print("Publisher : ",publ)
            print("Total Quantity in Hand : ",qty)
            print("Purchased On : ",d_o_purchase)
            print("===============================================================")
            if Rec_count%2==0:
                input("Press any key to continue")
                clrscreen()
            print(Rec_count, "Record(s) found")
          # Make sure data is committed to the database
            cnx.commit()
            Cursor.close()
            cnx.close()
    except mysql.connector.Error as err:
        if err.errno == errorcode.ER_ACCESS_DENIED_ERROR:
            print("Something is wrong with your user name or password")
        elif err.errno == errorcode.ER_BAD_DB_ERROR:
            print("Database does not exist")
        else:
            print(err)
    cnx.close()
    
def UpdateBook():
    try:
        cnx = connection.MySQLConnection(user='root',
                         password='mysql',
                         host='127.0.0.1',
                         database='Library')
         Cursor = cnx.cursor()


        bno=input("Enter Book Code of Book to be Updated from the Library : ")
        query = ("SELECT * FROM BookRecord where BNo = %s ")
        rec_srch=(bno,)


        print("Enter new data ")
        bname=input("Enter Book Name : ")
        Auth=input("Enter Book Author's Name : ")
        price=int(input("Enter Book Price : "))
        publ=input("Enter Publisher of Book : ")
        qty=int(input("Enter Quantity purchased : "))
        print("Enter Date of Purchase (Date/MOnth and Year seperately: ")
        DD=int(input("Enter Date : "))
        MM=int(input("Enter Month : "))
        YY=int(input("Enter Year : "))


        Qry = ("UPDATE BookRecord SET bname=%s,Author=%s,"\
            "price=%s,publisher=%s,qty=%s,d_o_purchase=%s "\
              "WHERE BNO=%s")
        data = (bname,Auth,price,publ,qty,date(YY,MM,DD),bno)


        Cursor.execute(Qry,data)
        # Make sure data is committed to the database'''
        cnx.commit()
        Cursor.close()
        cnx.close()
        print(Cursor.rowcount,"Record(s) Updated Successfully.............")
    except mysql.connector.Error as err: 
        if err.errno == errorcode.ER_ACCESS_DENIED_ERROR:
            print("Something is wrong with your user name or password")
        elif err.errno == errorcode.ER_BAD_DB_ERROR:
            print("Database does not exist")
        else:
            print(err)
    cnx.close()
    #UpdateBook()
#PYTHON MODULE : ISSUE
import mysql.connector
from mysql.connector import errorcode
from datetime import date
from mysql.connector import (connection)
import os


def clrscreen():
    print('\n' *5)

def ShowIssuedBooks():
    try:
        os.system('cls')
        cnx = connection.MySQLConnection(user='root', password='mysql',
                 host='localhost',
                 database='Library')
        Cursor = cnx.cursor()
        query = ("SELECT B.bno,bname,M.mno,mname,d_o_issue,d_o_ret FROM bookRecord B,issue I"\
                 ",member M where B.bno=I.bno and I.mno=M.mno")
        Cursor.execute(query)
        
        
        for (Bno,Bname,Mno,Mname,doi,dor) in Cursor:
            print("==============================================================")
            print("Book Code : ",Bno)
            print("Book Name : ",Bname)
            print("Member Code : ",Mno)
            print("Member Name : ",Mname)
            print("Date of issue : ",doi)
            print("Date of return : ",dor)

            print("===============================================================")
            
            
        Cursor.close()
        cnx.close()
        print("You have done it!!!!!!")
        except mysql.connector.Error as err:
            if err.errno == errorcode.ER_ACCESS_DENIED_ERROR:
                print("Something is wrong with your user name or password")
            elif err.errno == errorcode.ER_BAD_DB_ERROR:
                print("Database does not exist")
            else:
                print(err)
            else:
                cnx.close()


def issueBook():
    try:
        cnx = connection.MySQLConnection(user='root',
                         password='mysql',
                         host='127.0.0.1',
                         database='Library')
         Cursor = cnx.cursor()
            
            
        bno=input("Enter Book Code to issue : ")
        mno=input("Enter Member Code : ")
        print("Enter Date of Issue (Date/MOnth and Year seperately: ")
        DD=int(input("Enter Date : "))
        MM=int(input("Enter Month : "))
        YY=int(input("Enter Year : "))
        

        Qry = ("INSERT INTO issue (bno,mno,d_o_issue)"\
               "VALUES (%s, %s, %s)")
        data = (bno,mno,date(YY,MM,DD))
        Cursor.execute(Qry,data)
        cnx.commit()
        Cursor.close()
        cnx.close()
        print("Record Inserted..............")
        except mysql.connector.Error as err:
            if err.errno == errorcode.ER_ACCESS_DENIED_ERROR:
                print("Something is wrong with your user name or password")
            elif err.errno == errorcode.ER_BAD_DB_ERROR:
                print("Database does not exist")
            else:
                print(err)
                

            cnx.close()
            
            
            
            
def returnBook():
    try:
        cnx = connection.MySQLConnection(user='root',
                         password='mysql',
                         host='127.0.0.1',
                         database='Library')
        Cursor = cnx.cursor()
        
        
        bno=input("Enter Book Code of Book to be returned to the Library : ")
        Mno=input("Enter Member Code of Member who is returning Book : ")
        retDate=date.today()
        Qry =("""Update Issue set d_o_ret= %s WHERE BNO = %s and Mno= %s """)
        rec=(retDate,bno,Mno)
        Cursor.execute(Qry,rec)

        # Make sure data is committed to the database
        cnx.commit()
        Cursor.close()
        cnx.close()
        print(Cursor.rowcount,"Record(s) Deleted Successfully.............")
        except mysql.connector.Error as err:
            if err.errno == errorcode.ER_ACCESS_DENIED_ERROR:
                print("Something is wrong with your user name or password")
            elif err.errno == errorcode.ER_BAD_DB_ERROR:
                print("Database does not exist")
            else:
                print(err)

            cnx.close()

#PYTHON MODULE MEMBER
import mysql.connector
from mysql.connector import errorcode
from datetime import date, datetime, timedelta
from mysql.connector import (connection)
import os

def clrscreen():
    print('\n' *5)

def display():
    try:
        os.system('cls')
        cnx = connection.MySQLConnection(user='root', password='mysql',
                         host='localhost',
                         database='LIbrary')
        Cursor = cnx.cursor()
        query = ("SELECT * FROM Member")
        Cursor.execute(query)
        
        
        for (Mno,Mname,MOB,DOP,ADR) in Cursor:
            print("==============================================================")
            print("Member Code : ",Mno)
            print("Member Name : ",Mname)
            print("Mobile No.of Member : ",MOB)
            print("Date of Membership : ",DOP)
            print("Address : ",ADR)
            print("===============================================================")
            
            
        Cursor.close()
        cnx.close()
        print("You have done it!!!!!!")
        except mysql.connector.Error as err:
            if err.errno == errorcode.ER_ACCESS_DENIED_ERROR:
                print("Something is wrong with your user name or password")
            elif err.errno == errorcode.ER_BAD_DB_ERROR:
                print("Database does not exist")
            else:
                print(err)
            else:
                cnx.close()
                
                
                
                

def insertMember():
    try:
        cnx = connection.MySQLConnection(user='root',
                         password='mysql',
                         host='127.0.0.1',
                         database='Library')
        Cursor = cnx.cursor()
        
        
        mno=input("Enter Member Code : ")
        mname=input("Enter Member Name : ")
        mob=input("Enter Member Mobile No. : ")
        print("Enter Date of Membership (Date/MOnth and Year seperately: ")
        DD=int(input("Enter Date : "))
        MM=int(input("Enter Month : "))
        YY=int(input("Enter Year : "))
        addr=input("Enter Member Adress : ")
        Qry = ("INSERT INTO Member "\
                "VALUES (%s, %s, %s, %s, %s)")
        data = (mno,mname,mob,date(YY,MM,DD),addr)
        Cursor.execute(Qry,data)
        # Make sure data is committed to the database
        cnx.commit()
        Cursor.close()
        cnx.close()
        print("Record Inserted..............")
        except mysql.connector.Error as err:
            if err.errno == errorcode.ER_ACCESS_DENIED_ERROR:
                print("Something is wrong with your user name or password")
            elif err.errno == errorcode.ER_BAD_DB_ERROR:
                print("Database does not exist")
            else:
                print(err)
                

            cnx.close()
def deleteMember():
    try:
        cnx = connection.MySQLConnection(user='root',
                         password='mysql',
                         host='127.0.0.1',
                         database='Library')
        Cursor = cnx.cursor()
        
        
        mno=input("Enter Member Code to be deleted from the Library : ")

        Qry =("""DELETE FROM Member WHERE MNO = %s""")
        del_rec=(mno,)
        Cursor.execute(Qry,del_rec)

        # Make sure data is committed to the database
        cnx.commit()
        Cursor.close()
        cnx.close()
        print(Cursor.rowcount,"Record(s) Deleted Successfully.............")
        except mysql.connector.Error as err:
            if err.errno == errorcode.ER_ACCESS_DENIED_ERROR:
                print("Something is wrong with your user name or password")
            elif err.errno == errorcode.ER_BAD_DB_ERROR:
                print("Database does not exist")
            else:
                print(err)

            cnx.close()

def SearchMember():
    try:
        cnx = connection.MySQLConnection(user='root',
                         password='mysql',
                         host='127.0.0.1',
                         database='Library')
        Cursor = cnx.cursor()
        
        
        mnm=input("Enter Book Name to be Searched from the Library : ")
        query = ("SELECT * FROM Member where MName = %s ")
        rec_srch=(mnm,)
        Cursor.execute(query,rec_srch)

        Rec_count=0
        for (Mno,Mname,MOB,DOP,ADR) in Cursor:
            print("==============================================================")
            print("Member Code : ",Mno)
            print("Member Name : ",Mname)
            print("Mobile No.of Member : ",MOB)
            print("Date of Membership : ",DOP)
            print("Address : ",ADR)
            print("===============================================================")
        if Rec_count%2==0:
            input("Press any key to continue")
            clrscreen()
            print(Rec_count, "Record(s) found")
        # Make sure data is committed to the database
        cnx.commit()
        Cursor.close()
        cnx.close()

    except mysql.connector.Error as err:
        if err.errno == errorcode.ER_ACCESS_DENIED_ERROR:
            print("Something is wrong with your user name or password")
        elif err.errno == errorcode.ER_BAD_DB_ERROR:
            print("Database does not exist")
        else:
            print(err)
        cnx.close()
# Out:
#   File "<ipython-input-20-78c0125b9b0e>", line 271
#     cnx = connection.MySQLConnection(user='root',
#       ^
# IndentationError: expected an indented block
