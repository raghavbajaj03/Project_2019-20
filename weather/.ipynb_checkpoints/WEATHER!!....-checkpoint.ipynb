# %%
import os
import platform
import sqlite3 

############## Login Screen ##############    
def LOGIN():
    con=sqlite3.connect('SQLite_python.db')
    if(con):
        mycursor=con.cursor()
    while(1):
        l=[]
        user_id=input('ENTER USER ID')
        l.append(user_id)
        # Check if user_id already exists
        find_user="SELECT user_id FROM user_details WHERE user_id=?;"
        mycursor.execute(find_user,(user_id,))
        results=mycursor.fetchone()
        if results:
            print(results)
            if(user_id==results[0]):
                    print("User already exists,plese pick another username\n")
                    continue
        else:
            print("not fount \n")
            password=input('ENTER PASSWORD')
            l.append(password)
            #sql='''insert into user_details(user_id,password) values('%s','%s');'''
            sql='INSERT INTO user_details( user_id, password) VALUES ( ?,? )'
            mycursor.execute(sql,(user_id,password))
            con.commit()
            print("Login Successful \n")
        con.close()
        break

############## Sign Up Screen ############## 
def sign_up():
    con=sqlite3.connect('SQLite_python.db')
    if(con):
        mycursor=con.cursor()
    print('1.USER_ID')
    print('2.PASSWORD')
    ch=int(input('ENTER CHOICE'))
    if ch==1:
        userid=input('ENTER USER-ID')
        val=(userid,)
        sql="select * from user_details where user_id='%s';"
        mycursor.exeute(sql,val)
    elif ch==2:
        password=input('ENTER PASSWORD')
        password1=input('confirm password')
        val=(password1,)
        sql="select * from user_details where password='%s';"
        mycursor.exeute(sql,val)
    con.commit()
    con.close()

############## Guest Mode ############## 
def show_city_inf():
    import requests,json
    #api_key="cc9a28a7604bc8b3d0addd9b85ac8d21"
    #my api key
    api_key="ffed7bc78ee5dac9c811fd1393d88fc5"
    base_url="http://api.openweathermap.org/data/2.5/weather?"
    city_name=input("Enter City Name:")
    complete_url=base_url + "appid=" + api_key + "&q=" + city_name
    #complete_url="http://api.openweathermap.org/data/2.5/weather?"+"appid"+api_key+"&q"+city_name
    response=requests.get(complete_url)
    x=response.json()
    print(x)
    if x["cod"]!="404":
        y=x["main"]
        current_temperature=y["temp"]
        current_pressure=y["pressure"]
        current_humidity=["humidity"]
        z=x["weather"]
        weather_description=z[0]["description"]
        print(" Temperature (in kelvin unit) = " +
                    str(current_temperature) + 
          "\n atmospheric pressure (in hPa unit) = " +
                    str(current_pressure) +
          "\n humidity (in percentage) = " +
                    str(current_humidity) +
          "\n description = " +
                    str(weather_description)) 
    else:
        print(" City Not Found ") 
        
############## Main Menu ##############      
def MenuSet():
    runAgn ='y'
    while(runAgn.lower() == 'y'):
        print('ENTER NUMBER')
        print('1.LOGIN')
        print('2.SIGN_UP')
        print('3.CITY WEATHER')
        ch=int(input('ENTER YOUR CHOICE'))
        if ch==1:
            LOGIN()
        elif ch==2:
            sign_up()
        elif ch==3:
            show_city_inf()
        else:
            print("Wrong input try again\n")
            if(platform.system() == "Windows"):
                print(os.system('cls'))
            else:
                print(os.system('clear'))
        runAgn = input("\n want To Run Again Y/n: ")

############## Start from here ############## 
MenuSet()
# Out:
# ENTER NUMBER
# 1.LOGIN
# 2.SIGN_UP
# 3.CITY WEATHER
# ENTER YOUR CHOICE1
# ENTER USER IDcobra
# ('cobra',)
# User already exists,plese pick another username
#
# ENTER USER IDreva
# not fount
#
# ENTER PASSWORDwhatisthat
# Login Successful
#
#
#  want To Run Again Y/n: y
# ENTER NUMBER
# 1.LOGIN
# 2.SIGN_UP
# 3.CITY WEATHER
# ENTER YOUR CHOICE1
# ENTER USER IDreva
# ('reva',)
# User already exists,plese pick another username
#
# ENTER USER IDviddy
# not fount
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /Users/nmba/Library/Enthought/Canopy/edm/envs/User/lib/python3.5/site-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
#     718             try:
# --> 719                 ident, reply = self.session.recv(self.stdin_socket, 0)
#     720             except Exception:
#
# /Users/nmba/Library/Enthought/Canopy/edm/envs/User/lib/python3.5/site-packages/jupyter_client/session.py in recv(self, socket, mode, content, copy)
#     777         try:
# --> 778             msg_list = socket.recv_multipart(mode, copy=copy)
#     779         except zmq.ZMQError as e:
#
# /Users/nmba/Library/Enthought/Canopy/edm/envs/User/lib/python3.5/site-packages/zmq/sugar/socket.py in recv_multipart(self, flags, copy, track)
#     394         """
# --> 395         parts = [self.recv(flags, copy=copy, track=track)]
#     396         # have first part already, only loop while more to receive
#
# zmq/backend/cython/socket.pyx in zmq.backend.cython.socket.Socket.recv (zmq/backend/cython/socket.c:7288)()
#
# zmq/backend/cython/socket.pyx in zmq.backend.cython.socket.Socket.recv (zmq/backend/cython/socket.c:7086)()
#
# zmq/backend/cython/socket.pyx in zmq.backend.cython.socket._recv_copy (zmq/backend/cython/socket.c:2038)()
#
# /Users/nmba/Library/Enthought/Canopy/edm/envs/User/lib/python3.5/site-packages/zmq/backend/cython/checkrc.pxd in zmq.backend.cython.checkrc._check_rc (zmq/backend/cython/socket.c:7603)()
#
# KeyboardInterrupt:
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-13-97eae38f5d71> in <module>()
#     110
#     111 ############## Start from here ##############
# --> 112 MenuSet()
#
# <ipython-input-13-97eae38f5d71> in MenuSet()
#      96         ch=int(input('ENTER YOUR CHOICE'))
#      97         if ch==1:
# ---> 98             LOGIN()
#      99         elif ch==2:
#     100             sign_up()
#
# <ipython-input-13-97eae38f5d71> in LOGIN()
#      23         else:
#      24             print("not fount \n")
# ---> 25             password=input('ENTER PASSWORD')
#      26             l.append(password)
#      27             #sql='''insert into user_details(user_id,password) values('%s','%s');'''
#
# /Users/nmba/Library/Enthought/Canopy/edm/envs/User/lib/python3.5/site-packages/ipykernel/kernelbase.py in raw_input(self, prompt)
#     692             self._parent_ident,
#     693             self._parent_header,
# --> 694             password=False,
#     695         )
#     696
#
# /Users/nmba/Library/Enthought/Canopy/edm/envs/User/lib/python3.5/site-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
#     722             except KeyboardInterrupt:
#     723                 # re-raise KeyboardInterrupt, to truncate traceback
# --> 724                 raise KeyboardInterrupt
#     725             else:
#     726                 break
#
# KeyboardInterrupt:

# %%
# Python program to find current  
# weather details of any city 
# using openweathermap api 
  
# import required modules 
import requests, json 
  
# Enter your API key here 
api_key = "cc9a28a7604bc8b3d0addd9b85ac8d21"
  
# base_url variable to store url 
base_url = "http://api.openweathermap.org/data/2.5/weather?"
  
# Give city name 
city_name = input("Enter city name : ") 
  
# complete_url variable to store 
# complete url address 
complete_url = base_url + "appid=" + api_key + "&q=" + city_name 
  
# get method of requests module 
# return response object 
response = requests.get(complete_url) 
  
# json method of response object  
# convert json format data into 
# python format data 
x = response.json()
#print(x)
#print(x['main'])
#y=x['main']
#print(y)

if(x["cod"] != "404"): 
  
    # store the value of "main" 
    # key in variable y 
    y = x['main'] 
  
    # store the value corresponding 
    # to the "temp" key of y 
    current_temperature = y['temp'] 
  
    # store the value corresponding 
    # to the "pressure" key of y 
    current_pressure = y['pressure'] 
  
    # store the value corresponding 
    # to the "humidity" key of y 
    current_humidiy = y['humidity'] 
  
    # store the value of "weather" 
    # key in variable z 
    z = x['weather'] 
  
    # store the value corresponding  
    # to the "description" key at  
    # the 0th index of z 
    weather_description = z[0]['description'] 
  
    # print following values 
    print(" Temperature (in kelvin unit) = " +
                    str(current_temperature) + 
          "\n atmospheric pressure (in hPa unit) = " +
                    str(current_pressure) +
          "\n humidity (in percentage) = " +
                    str(current_humidiy) +
          "\n description = " +
                    str(weather_description)) 
  
else: 
    print(" City Not Found ")
# Out:
# Enter city name : chennai
#  Temperature (in kelvin unit) = 301.7
#  atmospheric pressure (in hPa unit) = 1016
#  humidity (in percentage) = 66
#  description = mist
