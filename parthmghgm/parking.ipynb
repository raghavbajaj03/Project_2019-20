# %%
import sqlite3
import os
import platform
from datetime import date

mydb=sqlite3.connect('SQLite.Python.db')
mycursor=mydb.cursor()
sqlite_createtable_query='''create table IF NOT EXISTS parkmaster11
                           (vid INTEGER NOT NULL PRIMARY KEY,
                            pname VARCHAR(21),
                            vname VARCHAR(21),
                            level1 VARCHAR(11),
                            freespace1 VARCHAR(5),
                            vehicleno1 VARCHAR,
                            nod1 INTEGER,
                            vehtype VARCHAR,
                            perdaycharge INTEGER
                            dateofpark TEXT,
                            payment1 INTEGER,
                            mobile_no INTEGER
                            );
'''
mycursor.execute(sqlite_createtable_query)

def add__record():
#mycursor.commit()
    l=[]
    vid=int(input('enter the parking number:'))
    l.append(vid)
    pname=input('enter the parking name:')
    pname=str(pname)
    l.append(pname)
    vname=input('enter vehicle model name')
    vname=str(vname)
    l.append(vname)
    
    level1=input('enter the level of parking:')
    l.append(level1)
    freespace1=input('is there any freespace or not: YES/NO')
    freespace1=str(freespace1)
    l.append(freespace1)
    vehicleno1=int(input('enter the vehicle number:'))
    l.append(vehicleno1)
    nod1=int(input('enter total no. of days of parking:'))
    l.append(nod1)
    vehtype=input('enter vehicle type')
    vehtype=str(vehtype)
    l.append(vehtype)
    print('car:200')
    print('bike:100')
    print('cycle:50')
    print('auto/autorickshaw:200')
    print('bus:300')
    print('truck:250')
    perdaycharge=int(input('enter per day charge'))
    l.append(perdaycharge)
    li_dt=str(input('enter in format dd-mm-yyyy')).split("-")
    dateofpark=date(int(li_dt[2]),int(li_dt[1]),int(li_dt[0]))
    l.append(dateofpark)
    payment1=perdaycharge*nod1
    l.append(payment1)
    mobile_no=int(input('enter mobile no'))
    l.append(mobile_no)
    stud=(l)
    sql='insert into parkmaster11(vid,pname,vname,level1,freespace1,vehicleno1,nod1,vehtype,perdaycharge,dateofpark,payment1,mobile_no)values(?,?,?,?,?,?,?,?,?,?,?,?)'
    mycursor.execute(sql,stud)
    mydb.commit()
    print('-----------------------------------------------------------------------------------------------')
    print('                               YOUR PARKING RECEIPT                                          ')
    print('-----------------------------------------------------------------------------------------------')
    print('  DATE:                                                                       ',dateofpark)
    print(' YOUR PARKING NO.:                                                              ',vid)
    print(' YOUR NAME:                                                                     ',pname)
    print(' YOUR VEHICLE NAME:                                                             ',vname)
    print(' YOUR VEHICLE NO.:                                                              ',vehicleno1)
    print(' PER DAY CHARGE:                                                                ',perdacharge)
    print(' NUMBER OF DAYS:                                                                ',nod1)    
    print('-----------------------------------------------------------------------------------------------')
    print(' YOUR PAYMENT:                                                                  ',payment1)
    print('-----------------------------------------------------------------------------------------------')
    print('-----------------------------------------------------------------------------------------------')
    print('                                      COME AGAIN :)                                          ')
    print('-----------------------------------------------------------------------------------------------')

    
def parking_table_view():
    print('select the search criteria:')
    print('1.Parking Number')
    print('2.Parking Name')
    print('3.Level No.')
    print('4.Vehicle No.')
    print('5.Date of Parking')
    print('6.All')
    ch= int(input('enter the choice'))
    if ch==1:
        s=int(input('enter parking no:'))
        rl=(s,)
        sql='select * from parkmaster11 where vid=%s'
        mycursor.execute(sql,rl)
    elif ch==2:
        s=input('enter parking name:')
        rl=(s,)
        sql='select * from parkmaster11 where pname=%s'
        mycursor.execute(sql,rl)
    elif ch==3:
        s=int(input('enter level of parking:'))
        r1=(s,)
        sql='select * from parkmaster11 where level1=%s'
        mycursor.execute(sql,rl)
    elif ch==4:
        s=int(input('enter vehicle no.:'))
        r1=(s,)
        sql='select * from parkmaster11 where vehicleno1=%s'
        mycursor.execute(sql,rl)
    elif ch==5:
        s=date('enter date of parking in format(year,month,day):')
        r1=(s,)
        sql='select * from parkmaster11 where dateofpark=%s'
        mycursor.execute(sql,rl)
    elif ch==6:
         
        sql='select * from parkmaster11'
        mycursor.execute(sql)
        res=mycursor.fetchall()
        print('DETAILS about parking are as follows:')
        print('Parking ID,Parking Name,Level,FreeSpace(Y/N),Vehicle No.,No. of days for parking,Payment')
        for x in res:
            print(x)
def checkout():
    vid=int(input('enter vid from receipt)'))
    s=(vid,)
    sql='select * from parkmaster11 where vid=%s'
    mycursor.execute(sql,s)  
    res=mycursor.fetchone()
    datepark=res[10] 
    li_dt=str(input('enter in format dd-mm-yyyy')).split("-")
    dateofpick=date(int(li_dt[2]),int(li_dt[1]),int(li_dt[0]))
    diff=dateofpick-datepark
    diff=diff.days
    vehtype=input('enter vehicle type')
    vehtype=str(vehtype)
    if vehtype=='car':
        perdaycharge=250
    elif vehtype=='bike':
        perdaycharge=150
    elif vehtype=='cycle':
        perdaycharge=100
    elif vehtype=='auto':
        perdaycharge=250
    elif vehtype=='bus':
        perdaycharge=350
    elif vehtype=='truck':
        perdaycharge=300
    penalty=diff*perdaycharge
    payment=res[9]
    total_payment=penalty+payment
    print('-----------------------------------------------------------------------------------------------')
    print('-----------------------------------------------------------------------------------------------')        
    print('                               ARROGANT SAMURAI PARKING SERVICES                                          ')
    print('-----------------------------------------------------------------------------------------------')
    print('  DATE:                                                                          ',dateofpick)
    print(' YOUR PARKING NO.:                                                               ',res[0])
    print(' YOUR NAME:                                                                      ',res[1])
    print(' YOUR VEHICLE NAME:                                                              ',res[2])
    print(' YOUR VEHICLE NO.:                                                               ',res[5])
    print(' PER DAY CHARGE:                                                                 ',res[8])
    print(' NUMBER OF DAYS:                                                                 ',res[6])
    print('')
    print('-----------------------------------------------------------------------------------------------')
    print(' YOUR PAYMENT:                                                                   ',payment)
    print(' YOUR PENALTY:                                                                   ',penalty)
    print('-----------------------------------------------------------------------------------------------')
    print('-----------------------------------------------------------------------------------------------')
    print('YOUR TOTAL PAYMENT:                                                              ',total_payment )
    print('-----------------------------------------------------------------------------------------------')
    print('                                      COME AGAIN :)                                            ')
    print('-----------------------------------------------------------------------------------------------')
def remove():
    print('REMOVE CRIETERIA')
    print('1. Parking No.')
    print('2. Parking Name')
    print('3. Vehicle No.')
    if ch==1:
        vid=int(input('enter the vehicle no. of the vehicle whose details is to be viewed:'))
        rl=(vid,)
        sql='delete from vehicle where vid=?'
        mycursor.execute(sql,rl)
        mydb.commit()
    elif ch==2:
        pname=input('enter the vehicle no. of the vehicle whose details is to be viewed:')
        pname=str(pname)
        rl=(pname,)
        sql='delete from vehicle where pname=?'
        mycursor.execute(sql,rl)
        mydb.commit()
    elif ch==3:
        vehicleno1=int(input('enter the vehicle no. of the vehicle whose details is to be viewed:'))
        rl=(vehicleno1,)
        sql='delete from vehicle where vehicleno1=?'
        mycursor.execute(sql,rl)
        mydb.commit()
def Menu():
    print('ENTER 1:TO ADD PARKING DETAIL')
    print('ENTER 2:TO VIEW PARKING DETAIL')
    print('ENTER 3:TO FINAL RECEIPT')
    print('ENTER 4:TO REMOVE  RECORD')
    print('ENTER 5:TO SEE THE DETAILS OF VEHICLE')
    option=int(input('please select an above option'))
    if option==1:
        add__record()
    if option==2:
        parking_table_view()
    if option==3:
        checkout()
    if option==4:
        remove()
    if option==5:
        Menu()
def run_again():
    unagn=input(' \nwant to run again Y/n":')
    while(unagn.lower()=='y'):
        if(platform.system()=='Windows'):
            print(os.system('cls'))
        else:
            print(os.system('clear'))
Menu()
run_again=input('\nwant to run again Y/n')
run_again()
# Out:
# ENTER 1:TO ADD PARKING DETAIL
# ENTER 2:TO VIEW PARKING DETAIL
# ENTER 3:TO FINAL RECEIPT
# ENTER 4:TO REMOVE  RECORD
# ENTER 5:TO SEE THE DETAILS OF VEHICLE
# please select an above option1
# enter the parking number:1002
# enter the parking name:anita
# enter vehicle model nameswift
# enter the level of parking:3
# is there any freespace or not: YES/NOyes
# enter the vehicle number:9989
# enter total no. of days of parking:3
# enter vehicle typecar
# car:200
# bike:100
# cycle:50
# auto/autorickshaw:200
# bus:300
# truck:250
# enter per day charge200
# enter in format dd-mm-yyyy12-09-2019
# enter mobile no09876554321
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# <ipython-input-5-897622d00470> in <module>()
#     224         else:
#     225             print(os.system('clear'))
# --> 226 Menu()
#     227 run_again=input('\nwant to run again Y/n')
#     228 run_again()
#
# <ipython-input-5-897622d00470> in Menu()
#     208     option=int(input('please select an above option'))
#     209     if option==1:
# --> 210         add__record()
#     211     if option==2:
#     212         parking_table_view()
#
# <ipython-input-5-897622d00470> in add__record()
#      64     stud=(l)
#      65     sql='insert into parkmaster11(vid,pname,vname,level1,freespace1,vehicleno1,nod1,vehtype,perdaycharge,dateofpark,payment1,mobile_no)values(?,?,?,?,?,?,?,?,?,?,?,?)'
# ---> 66     mycursor.execute(sql,stud)
#      67     mydb.commit()
#      68     print('-----------------------------------------------------------------------------------------------')
#
# OperationalError: table parkmaster11 has no column named payment1

# %%
no=1
no=string('no')

# %%
from datetime import date

d0 = date(2008, 8, 18)
d1 = date(2008, 9, 26)
delta = d1 - d0
print(delta.days)

# %%
mobile_no=int(input('enter mobile no'))
print("Mobile No.",mobile_no)
# Out:
# enter mobile no0987654321
# ('Mobile No.', 987654321)

# %%
mydb=sqlite3.connect('SQLite.Python.db')
mycursor=mydb.cursor()
sql='select * from parkmaster11'
mycursor.execute(sql)
res=mycursor.fetchall()
print('DETAILS about parking are as follows:')
print('Parking ID,Parking Name,Level,FreeSpace(Y/N),Vehicle No.,No. of days for parking,Payment')
for x in res:
    print(x)
# Out:
# DETAILS about parking are as follows:
# Parking ID,Parking Name,Level,FreeSpace(Y/N),Vehicle No.,No. of days for parking,Payment
# (1001, u'abc', u'def', u'2', u'no', u'4567', 2, u'car', 200, u'22-10-2019', 400, 746454544536L)
